# %% [markdown]
# # Use-case 2: Linking content data to ratings data

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Preparing environment

# %%
import pandas as pd

df_rating = pd.read_csv('data/banijay_op1data_ratings_processed.csv', compression='zip')
df_content = pd.read_csv('data/banijay_op1data_content_processed.csv', compression='zip')

# %%
del df_rating['Unnamed: 0'] #Deleting this column, because it was created unintentionally.
df_rating.head(10)
# Out:
#         Datum      Time Program Station        Target Group  \
# 0  2020-01-06  22:18:00     op1    npo1            tot6plus
# 1  2020-01-06  22:18:00     op1    npo1            tot6plus
# 2  2020-01-06  22:18:00     op1    npo1            tot6plus
# 3  2020-01-06  22:18:00     op1    npo1  boodschapper_20_49
# 4  2020-01-06  22:18:00     op1    npo1  boodschapper_20_49
# 5  2020-01-06  22:18:00     op1    npo1  boodschapper_20_49
# 6  2020-01-06  22:18:00     op1    npo1  boodschapper_25_54
# 7  2020-01-06  22:18:00     op1    npo1  boodschapper_25_54
# 8  2020-01-06  22:18:00     op1    npo1  boodschapper_25_54
# 9  2020-01-06  22:18:00     op1    npo1             6_12_jr
#
#                   Broadcast Type Ratings Type       Kdh%       Kdh000  \
# 0  live/prerecorded uitzendingen   uitzenddag   9.676969  1546.863437
# 1  live/prerecorded uitzendingen   uitgesteld   1.484044   237.224411
# 2  live/prerecorded uitzendingen       totaal  10.299407  1646.360210
# 3  live/prerecorded uitzendingen   uitzenddag   3.217735   117.833443
# 4  live/prerecorded uitzendingen   uitgesteld   1.146627    41.989484
# 5  live/prerecorded uitzendingen       totaal   3.975244   145.573420
# 6  live/prerecorded uitzendingen   uitzenddag   5.294855   212.111904
# 7  live/prerecorded uitzendingen   uitgesteld   1.662682    66.607030
# 8  live/prerecorded uitzendingen       totaal   6.271663   251.242825
# 9  live/prerecorded uitzendingen   uitzenddag   1.025859    13.510569
#
#        Zadl%            date_time
# 0  30.881672  2020-01-06 22:18:00
# 1  24.692727  2020-01-06 22:18:00
# 2  29.962268  2020-01-06 22:18:00
# 3  14.746563  2020-01-06 22:18:00
# 4  17.021271  2020-01-06 22:18:00
# 5  15.812862  2020-01-06 22:18:00
# 6  19.696293  2020-01-06 22:18:00
# 7  22.868945  2020-01-06 22:18:00
# 8  20.356892  2020-01-06 22:18:00
# 9  43.995912  2020-01-06 22:18:00

# %%
df_content.head()
# Out:
#    Unnamed: 0        date                                              hosts  \
# 0           0  01-02-2021           ['Hilbrand, Sophie', 'Logtenberg, Hugo']
# 1           1  01-02-2021           ['Hilbrand, Sophie', 'Logtenberg, Hugo']
# 2           2  01-02-2021           ['Hilbrand, Sophie', 'Logtenberg, Hugo']
# 3           3  01-02-2021           ['Hilbrand, Sophie', 'Logtenberg, Hugo']
# 4           4  01-02-2022  ['Brink, Tijs van den', 'Ostiana, Giovanca', '...
#
#                                      id    length     start       end  \
# 0  OP1__________-WON02197428_01_segment  00:21:21  22:20:11  22:41:32
# 1  OP1__________-WON02197428_02_segment  00:11:04  22:41:36  22:52:41
# 2  OP1__________-WON02197428_03_segment  00:11:15  22:53:04  23:04:20
# 3  OP1__________-WON02197428_04_segment  00:11:20  23:04:22  23:15:39
# 4  OP1__________-WON02290378_01_segment  00:06:22  22:38:18  22:44:40
#
#                                                title  \
# 0  Gerard Smetsers, Annelie Jager en Károly Illy ...
# 1  IC-arts Hugo Touw wil versoepeling van de coro...
# 2  Feike Sijbesma over de gevolgen van de klimaat...
# 3  Danny Ghosen en ex-designerdrugsverslaafde Kev...
# 4            Op1 - De opening van dinsdag 1 februari
#
#                                              summary  \
# 0  De basisscholen mogen weer open, maar dat bete...
# 1  Intensivisten pleiten voor versoepeling van de...
# 2  Volgens ex-coronagezant Feike Sijbesma is de c...
# 3  Steeds vaker komen er meldingen binnen van men...
# 4  Marc van der Linden, Jeroen Snel en Jesse Klav...
#
#                                         keywords      date_time_start  \
# 0      ['directeur', 'gesloten', 'basisscholen']  2021-01-02 22:20:11
# 1  ['accepteren', 'waarom', 'coronamaatregelen']  2021-01-02 22:41:36
# 2     ['snel', 'wereldleiders', 'klimaatcrisis']  2021-01-02 22:53:04
# 3     ['nieuwste', 'combinatie', 'designerdrug']  2021-01-02 23:04:22
# 4                   ['snel', 'linden', 'nieuws']  2022-01-02 22:38:18
#
#          date_time_end                    show_id   fragment
# 0  2021-01-02 22:41:32  OP1__________-WON02197428  1_segment
# 1  2021-01-02 22:52:41  OP1__________-WON02197428  2_segment
# 2  2021-01-02 23:04:20  OP1__________-WON02197428  3_segment
# 3  2021-01-02 23:15:39  OP1__________-WON02197428  4_segment
# 4  2022-01-02 22:44:40  OP1__________-WON02290378  1_segment

# %%
del df_content['Unnamed: 0']

# %%
#Credits to Kian for the code below!

arr = [] # Creating an array
for x in df_rating["date_time"]: # For each value in column:
    fragment = df_content.loc[(df_content['date_time_start'] <= x) & (df_content['date_time_end'] >= x)] # Locate the row belonging to that value and storing it in fragment.
    if fragment.shape[0] == 0 :
        arr.append(None) # If fragment does not have a value append nothing; else append id.
    else:
        arr.append(fragment.iloc[0]['id']) # I am merging on id, which includes show and fragment.

df_rating['id'] = pd.Series(arr).values # Convert the array into a series which can be put into a column in the ratings data.

# %%
df_merged = pd.merge(df_rating, df_content, how="left", on='id') # Merge the data set with the column I created just now.

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1251982 entries, 0 to 1251981
# Data columns (total 24 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Datum            1251982 non-null  object
#  1   Time             1251982 non-null  object
#  2   Program          1251982 non-null  object
#  3   Station          1251982 non-null  object
#  4   Target Group     1251982 non-null  object
#  5   Broadcast Type   1251982 non-null  object
#  6   Ratings Type     1251982 non-null  object
#  7   Kdh%             1251982 non-null  float64
#  8   Kdh000           1251982 non-null  float64
#  9   Zadl%            1251982 non-null  float64
#  10  date_time        1251982 non-null  object
#  11  id               858449 non-null   object
#  12  date             858449 non-null   object
#  13  hosts            858449 non-null   object
#  14  length           858449 non-null   object
#  15  start            858449 non-null   object
#  16  end              858449 non-null   object
#  17  title            858449 non-null   object
#  18  summary          858449 non-null   object
#  19  keywords         858449 non-null   object
#  20  date_time_start  858449 non-null   object
#  21  date_time_end    858449 non-null   object
#  22  show_id          858449 non-null   object
#  23  fragment         858449 non-null   object
# dtypes: float64(3), object(21)
# memory usage: 238.8+ MB

# %%
df_merged = df_merged.dropna() # Drop all rows that have no value.

# %%
df_merged.info() # Check the Non-Null values to see if the code provided above worked.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 858449 entries, 0 to 1235248
# Data columns (total 24 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Datum            858449 non-null  object
#  1   Time             858449 non-null  object
#  2   Program          858449 non-null  object
#  3   Station          858449 non-null  object
#  4   Target Group     858449 non-null  object
#  5   Broadcast Type   858449 non-null  object
#  6   Ratings Type     858449 non-null  object
#  7   Kdh%             858449 non-null  float64
#  8   Kdh000           858449 non-null  float64
#  9   Zadl%            858449 non-null  float64
#  10  date_time        858449 non-null  object
#  11  id               858449 non-null  object
#  12  date             858449 non-null  object
#  13  hosts            858449 non-null  object
#  14  length           858449 non-null  object
#  15  start            858449 non-null  object
#  16  end              858449 non-null  object
#  17  title            858449 non-null  object
#  18  summary          858449 non-null  object
#  19  keywords         858449 non-null  object
#  20  date_time_start  858449 non-null  object
#  21  date_time_end    858449 non-null  object
#  22  show_id          858449 non-null  object
#  23  fragment         858449 non-null  object
# dtypes: float64(3), object(21)
# memory usage: 163.7+ MB

# %%
df_merged.to_csv('data/banijay_op1data_content_ratings.csv', compression='zip') # Saving the merged dataset.
